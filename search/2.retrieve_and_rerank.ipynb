# %% [markdown]
# # Semantic Search
#
# Improvement on the previous notebook. It includes:
# * Embedding and Retrieval: Uses SentenceTransformer for fast embedding-based similarity search (basic retrieval) to select top-k candidates based on semantic similarity.
# * Re-ranking with CrossEncoder: Adds a second level of complexity by using a CrossEncoder model to re-rank the retrieved candidates based on query-context relevance.
# * Boosting Scores: Introduces additional score boosts for candidates whose store names or titles include keywords from the query.

# %%
import os
import numpy as np
import pandas as pd
from tqdm import tqdm

from datasets import load_dataset
from sentence_transformers import SentenceTransformer, CrossEncoder
from sklearn.metrics.pairwise import cosine_similarity

os.chdir("../")
from aux.text_pre_processing import (
    combine_text_features,
    pre_process_text,
    pre_process_query,
)

pd.set_option("display.max_colwidth", 150)
tqdm.pandas()

# %% [markdown]
# # Load Data

# %%
dataset_items = load_dataset(
    "McAuley-Lab/Amazon-Reviews-2023",
    "raw_meta_All_Beauty",
    split="full",
    trust_remote_code=True,
)
df = dataset_items.to_pandas()

# %%
df.head()
# Out:
#   main_category  \
# 0    All Beauty
# 1    All Beauty
# 2    All Beauty
# 3    All Beauty
# 4    All Beauty
#
#                                                                                                                                                    title  \
# 0                                                                                                    Howard LC0008 Leather Conditioner, 8-Ounce (4-Pack)
# 1        Yes to Tomatoes Detoxifying Charcoal Cleanser (Pack of 2) with Charcoal Powder, Tomato Fruit Extract, and Gingko Biloba Leaf Extract, 5 fl. oz.
# 2                                                                                                       Eye Patch Black Adult with Tie Band (6 Per Pack)
# 3  Tattoo Eyebrow Stickers, Waterproof Eyebrow, 4D Imitation Eyebrow Tattoos, 4D Hair-like Authentic Eyebrows Waterproof Long Lasting for Woman & Man...
# 4                                                                                 Precision Plunger Bars for Cartridge Grips – 93mm – Bag of 10 Plungers
#
#    average_rating  rating_number  \
# 0             4.8             10
# 1             4.5              3
# 2             4.4             26
# 3             3.1            102
# 4             4.3              7
#
#                                                                                                                                                 features  \
# 0                                                                                                                                                     []
# 1                                                                                                                                                     []
# 2                                                                                                                                                     []
# 3                                                                                                                                                     []
# 4  [Material: 304 Stainless Steel; Brass tip, Lengths Available: 88mm, 93mm, 98mm, Accepts cartridge needles with vice style tattoo machines, Works p...
#
#                                                                                                                                              description  \
# 0                                                                                                                                                     []
# 1                                                                                                                                                     []
# 2                                                                                                                                                     []
# 3                                                                                                                                                     []
# 4  [The Precision Plunger Bars are designed to work seamlessly with the Precision Disposable 1. 25" Contoured Soft Cartridge Grips and the Precision ...
#
#   price  \
# 0  None
# 1  None
# 2  None
# 3  None
# 4  None
#
#                                                                                                                                                   images  \
# 0  {'hi_res': [None, 'https://m.media-amazon.com/images/I/71i77AuI9xL._SL1500_.jpg'], 'large': ['https://m.media-amazon.com/images/I/41qfjSfqNyL.jpg'...
# 1  {'hi_res': ['https://m.media-amazon.com/images/I/71g1lP0pMbL._SL1500_.jpg', 'https://m.media-amazon.com/images/I/81OqvR94isL._SL1500_.jpg'], 'larg...
# 2  {'hi_res': [None, None], 'large': ['https://m.media-amazon.com/images/I/31bz+uqzWCL.jpg', 'https://m.media-amazon.com/images/I/31bz+uqzWCL.jpg'], ...
# 3  {'hi_res': ['https://m.media-amazon.com/images/I/71GJhXQGvyL._SL1500_.jpg', 'https://m.media-amazon.com/images/I/61NS1lONhzL._SL1001_.jpg', 'https...
# 4  {'hi_res': [None], 'large': ['https://m.media-amazon.com/images/I/31TgqAZ8kQL.jpg'], 'thumb': ['https://m.media-amazon.com/images/I/31TgqAZ8kQL._S...
#
#                                     videos                   store categories  \
# 0  {'title': [], 'url': [], 'user_id': []}         Howard Products         []
# 1  {'title': [], 'url': [], 'user_id': []}                  Yes To         []
# 2  {'title': [], 'url': [], 'user_id': []}  Levine Health Products         []
# 3  {'title': [], 'url': [], 'user_id': []}                Cherioll         []
# 4  {'title': [], 'url': [], 'user_id': []}               Precision         []
#
#                                                                                                                                                  details  \
# 0                                                                     {"Package Dimensions": "7.1 x 5.5 x 3 inches; 2.38 Pounds", "UPC": "617390882781"}
# 1  {"Item Form": "Powder", "Skin Type": "Acne Prone", "Brand": "Yes To", "Age Range (Description)": "Adult", "Unit Count": "10 Fl Oz", "Is Discontinu...
# 2                                                                                                             {"Manufacturer": "Levine Health Products"}
# 3  {"Brand": "Cherioll", "Item Form": "Powder", "Finish Type": "Natural", "Product Benefits": "Long Lasting", "Skin Type": "All", "Package Dimensions...
# 4                                                                                                                                {"UPC": "644287689178"}
#
#   parent_asin bought_together subtitle author
# 0  B01CUPMQZE            None     None   None
# 1  B076WQZGPM            None     None   None
# 2  B000B658RI            None     None   None
# 3  B088FKY3VD            None     None   None
# 4  B07NGFDN6G            None     None   None

# %%
df.columns
# Out:
# Index(['main_category', 'title', 'average_rating', 'rating_number', 'features',
#        'description', 'price', 'images', 'videos', 'store', 'categories',
#        'details', 'parent_asin', 'bought_together', 'subtitle', 'author'],
#       dtype='object')

# %% [markdown]
# ## Pre process

# %%
# item features
df["title_description_features"] = df.apply(
    lambda row: combine_text_features(
        row, col1="title", col2="features", col3="description"
    ),
    axis=1,
)
df = pre_process_text(
    df,
    input_col="title_description_features",
    output_col="product_title_description_feature_pre_processed",
)

df.loc[df.store.isnull(), "store"] = "unknown"
df = pre_process_text(df, input_col="store", output_col="store_pre_processed")

# %% [markdown]
# ##  Filter by minimum ammount of words
#
# * some of the shorter descriptions are bad

# %%
df["num_words"] = df["title_description_features"].str.split().str.len()

# %%
df[df.num_words >= 5].shape[0] / df.shape[0]
# Out:
# 0.9855671018740563

# %%
df = df.loc[df.num_words >= 5].reset_index(drop=True)

# %%
df.product_title_description_feature_pre_processed.head()
# Out:
# 0                                                                                                                 howard lc leather conditioner ounce pack
# 1                                      yes tomato detoxifying charcoal cleanser pack charcoal powder tomato fruit extract gingko biloba leaf extract fl oz
# 2                                                                                                                  eye patch black adult tie band per pack
# 3              tattoo eyebrow sticker waterproof eyebrow imitation eyebrow tattoo hairlike authentic eyebrow waterproof long lasting woman man makeup tool
# 4    precision plunger bar cartridge grip mm bag plunger precision plunger bar designed work seamlessly precision disposable contoured soft cartridge g...
# Name: product_title_description_feature_pre_processed, dtype: object

# %%
df.shape
# Out:
# (110965, 20)

# %%
# Model

# %%
bi_encoder = SentenceTransformer("all-MiniLM-L6-v2")  # fast retrieval
cross_encoder = CrossEncoder("cross-encoder/ms-marco-MiniLM-L-6-v2")  # Accurate ranking

# %%
document_embeddings = np.load("search/product_embeddings.npy")
document_embeddings.shape
# Out:
# (110965, 384)

# %%
# Features

# %%
def basic_retrieve(query, df, document_embeddings, retrieval_k=100):
    query = pre_process_query(query)
    query_embedding = bi_encoder.encode(query)
    similarity_scores = cosine_similarity([query_embedding], document_embeddings)[0]

    top_k_indices = np.argsort(similarity_scores)[-retrieval_k:]
    candidates = df.iloc[top_k_indices].copy()

    candidates.loc[:, "final_score"] = similarity_scores[top_k_indices]
    return candidates.sort_values("final_score", ascending=False)

# %%
def retrieve_and_rerank(
    query,
    df,
    document_embeddings,
    retrieval_k=100,
    use_title_keyword_match=False,
    use_store=False,
):
    # 1. semantic similarities
    query = pre_process_query(query)
    query_embedding = bi_encoder.encode(query)
    similarity_scores = cosine_similarity([query_embedding], document_embeddings)[0]

    top_k_indices = np.argsort(similarity_scores)[-retrieval_k:]
    candidates = df.iloc[top_k_indices].copy()

    # 2. rerank with store info
    if use_store:
        pairs = [
            [query, f"{text} [Brand: {store}]"]
            for text, store in zip(
                candidates["product_title_description_feature_pre_processed"],
                candidates["store"],
            )
        ]
    else:
        pairs = [
            [query, text]
            for text in candidates["product_title_description_feature_pre_processed"]
        ]

    rerank_scores = cross_encoder.predict(pairs)

    # 3. boosts after reranking
    final_scores = rerank_scores.copy()
    query_terms = query.lower().split()

    if use_title_keyword_match:
        title_matches = (
            candidates["title"]
            .str.lower()
            .apply(lambda x: any(term in x.lower() for term in query_terms))
        )
        final_scores += title_matches.astype(float) * 3

    if use_store:
        store_matches = (
            candidates["store"]
            .str.lower()
            .apply(lambda x: any(term in x.lower() for term in query_terms))
        )
        final_scores += store_matches.astype(float) * 3

    candidates.loc[:, "final_score"] = final_scores
    return candidates.sort_values("final_score", ascending=False)

# %%
query = "cerave spf moisturizer"
res = basic_retrieve(query, df, document_embeddings)
res[["title", "store", "final_score"]].head(10)
# Out:
#                                                                                                                                                        title  \
# 80371                                                                                                           Revitalizing Light-Weight Moisturizer SPF 15
# 62664  C'est Moi Tinted Moisturizing Lotion SPF 30 | Gentle, Hydrating Formula Provides Broad Spectrum SPF Protection with Sheer, Buildable Coverage, Fra...
# 38057  C'est Moi Tinted Moisturizing Lotion SPF 30 | Gentle, Hydrating Formula Provides Broad Spectrum SPF Protection with Sheer, Buildable Coverage, Fra...
# 95664  C'est Moi Tinted Moisturizing Lotion SPF 30 | Gentle, Hydrating Formula Provides Broad Spectrum SPF Protection with Sheer, Buildable Coverage, Fra...
# 4509   C'est Moi Tinted Moisturizing Lotion SPF 30 | Gentle, Hydrating Formula Provides Broad Spectrum SPF Protection with Sheer, Buildable Coverage, Fra...
# 28803                                                                                         Face Cream Moisturizer Olive Oil & Honey for Women SPF-20 50ml
# 83064                                                      Cerave Moisturizing Cream With Pump For Normal To Dry Skin Value Pack of 2 x 19 Oz (Total 38 Oz)"
# 31957                Cerave Sunscreen Bundle SPF 50 | Contains Mineral Sunscreen for Face SPF 50, 2.5 Ounce, and Mineral Body Sunscreen SPF 50, 5 Ounce 1 ea
# 99815                                                                                 Sofina Jenne Moisturizing Whitening UV Cut Emulsion SPF50+/PA++++/30ml
# 57652                                                                          Céla Skin Care Essential Balm, Coconut/Bergamot Oil Moisturizer for Dry Skin
#
#                                    store  final_score
# 80371                       BB Lifestyle     0.721638
# 62664                          C'est Moi     0.708719
# 38057                          C'est Moi     0.705689
# 95664                          C'est Moi     0.703798
# 4509                           C'est Moi     0.700271
# 28803  Health & Beauty Dead Sea Minerals     0.699831
# 83064                            LUXSURE     0.690701
# 31957                             CeraVe     0.686267
# 99815                             Sofina     0.680897
# 57652                               Céla     0.679205

# %%
query = "cerave spf moisturizer"
res = retrieve_and_rerank(
    query, df, document_embeddings, use_title_keyword_match=False, use_store=False
)
res[["title", "store", "final_score"]].head(10)
# Out:
#                                                                                                                                                         title  \
# 10143                                      CeraVe AM Facial Moisturizing Lotion SPF 30 | Oil-Free Face Moisturizer with Sunscreen | Non-Comedogenic | 3 Ounce
# 83064                                                       Cerave Moisturizing Cream With Pump For Normal To Dry Skin Value Pack of 2 x 19 Oz (Total 38 Oz)"
# 95664   C'est Moi Tinted Moisturizing Lotion SPF 30 | Gentle, Hydrating Formula Provides Broad Spectrum SPF Protection with Sheer, Buildable Coverage, Fra...
# 38057   C'est Moi Tinted Moisturizing Lotion SPF 30 | Gentle, Hydrating Formula Provides Broad Spectrum SPF Protection with Sheer, Buildable Coverage, Fra...
# 4509    C'est Moi Tinted Moisturizing Lotion SPF 30 | Gentle, Hydrating Formula Provides Broad Spectrum SPF Protection with Sheer, Buildable Coverage, Fra...
# 62664   C'est Moi Tinted Moisturizing Lotion SPF 30 | Gentle, Hydrating Formula Provides Broad Spectrum SPF Protection with Sheer, Buildable Coverage, Fra...
# 31957                 Cerave Sunscreen Bundle SPF 50 | Contains Mineral Sunscreen for Face SPF 50, 2.5 Ounce, and Mineral Body Sunscreen SPF 50, 5 Ounce 1 ea
# 107879                                                                                                                    CeraVe Hydrating Oil Cleanser 236ml
# 20208                                                                                                               Cetaphil Moisturizing Cream 20 oz, 2 Pack
# 68802                                                       Clinique 'Moisture Surge' Tinted Moisturizer SPF 15 Provides a No-Makeup Look and Feel (Shade 02)
#
#             store  final_score
# 10143      CeraVe     7.079282
# 83064     LUXSURE     4.998802
# 95664   C'est Moi     4.595958
# 38057   C'est Moi     4.507841
# 4509    C'est Moi     4.495101
# 62664   C'est Moi     4.448800
# 31957      CeraVe     4.172186
# 107879     CeraVe     2.804509
# 20208    Cetaphil     2.115604
# 68802     unknown     2.050982

# %%
query = "cerave spf moisturizer"
res = retrieve_and_rerank(
    query, df, document_embeddings, use_title_keyword_match=True, use_store=False
)
res[["title", "store", "final_score"]].head(10)
# Out:
#                                                                                                                                                         title  \
# 10143                                      CeraVe AM Facial Moisturizing Lotion SPF 30 | Oil-Free Face Moisturizer with Sunscreen | Non-Comedogenic | 3 Ounce
# 83064                                                       Cerave Moisturizing Cream With Pump For Normal To Dry Skin Value Pack of 2 x 19 Oz (Total 38 Oz)"
# 95664   C'est Moi Tinted Moisturizing Lotion SPF 30 | Gentle, Hydrating Formula Provides Broad Spectrum SPF Protection with Sheer, Buildable Coverage, Fra...
# 38057   C'est Moi Tinted Moisturizing Lotion SPF 30 | Gentle, Hydrating Formula Provides Broad Spectrum SPF Protection with Sheer, Buildable Coverage, Fra...
# 4509    C'est Moi Tinted Moisturizing Lotion SPF 30 | Gentle, Hydrating Formula Provides Broad Spectrum SPF Protection with Sheer, Buildable Coverage, Fra...
# 62664   C'est Moi Tinted Moisturizing Lotion SPF 30 | Gentle, Hydrating Formula Provides Broad Spectrum SPF Protection with Sheer, Buildable Coverage, Fra...
# 31957                 Cerave Sunscreen Bundle SPF 50 | Contains Mineral Sunscreen for Face SPF 50, 2.5 Ounce, and Mineral Body Sunscreen SPF 50, 5 Ounce 1 ea
# 107879                                                                                                                    CeraVe Hydrating Oil Cleanser 236ml
# 68802                                                       Clinique 'Moisture Surge' Tinted Moisturizer SPF 15 Provides a No-Makeup Look and Feel (Shade 02)
# 78162                  Murad Oil and Pore Control Mattifier Broad Spectrum SPF 45 | PA++++ | Travel Size - 0.8 Fl Oz - Moisturizer for Mattifying Facial Skin
#
#             store  final_score
# 10143      CeraVe    10.079282
# 83064     LUXSURE     7.998802
# 95664   C'est Moi     7.595958
# 38057   C'est Moi     7.507841
# 4509    C'est Moi     7.495101
# 62664   C'est Moi     7.448800
# 31957      CeraVe     7.172186
# 107879     CeraVe     5.804509
# 68802     unknown     5.050982
# 78162       Murad     4.963304

# %%
query = "cerave spf moisturizer"
res = retrieve_and_rerank(
    query, df, document_embeddings, use_title_keyword_match=True, use_store=True
)
res[["title", "store", "final_score"]].head(10)
# Out:
#                                                                                                                                                         title  \
# 10143                                      CeraVe AM Facial Moisturizing Lotion SPF 30 | Oil-Free Face Moisturizer with Sunscreen | Non-Comedogenic | 3 Ounce
# 31957                 Cerave Sunscreen Bundle SPF 50 | Contains Mineral Sunscreen for Face SPF 50, 2.5 Ounce, and Mineral Body Sunscreen SPF 50, 5 Ounce 1 ea
# 107879                                                                                                                    CeraVe Hydrating Oil Cleanser 236ml
# 83064                                                       Cerave Moisturizing Cream With Pump For Normal To Dry Skin Value Pack of 2 x 19 Oz (Total 38 Oz)"
# 95664   C'est Moi Tinted Moisturizing Lotion SPF 30 | Gentle, Hydrating Formula Provides Broad Spectrum SPF Protection with Sheer, Buildable Coverage, Fra...
# 4509    C'est Moi Tinted Moisturizing Lotion SPF 30 | Gentle, Hydrating Formula Provides Broad Spectrum SPF Protection with Sheer, Buildable Coverage, Fra...
# 38057   C'est Moi Tinted Moisturizing Lotion SPF 30 | Gentle, Hydrating Formula Provides Broad Spectrum SPF Protection with Sheer, Buildable Coverage, Fra...
# 62664   C'est Moi Tinted Moisturizing Lotion SPF 30 | Gentle, Hydrating Formula Provides Broad Spectrum SPF Protection with Sheer, Buildable Coverage, Fra...
# 68802                                                       Clinique 'Moisture Surge' Tinted Moisturizer SPF 15 Provides a No-Makeup Look and Feel (Shade 02)
# 78162                  Murad Oil and Pore Control Mattifier Broad Spectrum SPF 45 | PA++++ | Travel Size - 0.8 Fl Oz - Moisturizer for Mattifying Facial Skin
#
#             store  final_score
# 10143      CeraVe    13.063652
# 31957      CeraVe    10.687904
# 107879     CeraVe     9.319592
# 83064     LUXSURE     8.185555
# 95664   C'est Moi     7.732594
# 4509    C'est Moi     7.629389
# 38057   C'est Moi     7.623445
# 62664   C'est Moi     7.560297
# 68802     unknown     5.124448
# 78162       Murad     4.921179

# %%
# best one so far
query = "cerave spf moisturizer"
res = retrieve_and_rerank(
    query, df, document_embeddings, use_title_keyword_match=True, use_store=True
)
res[["title", "store", "final_score"]].head(10)
# Out:
#                                                                                                                                                         title  \
# 10143                                      CeraVe AM Facial Moisturizing Lotion SPF 30 | Oil-Free Face Moisturizer with Sunscreen | Non-Comedogenic | 3 Ounce
# 31957                 Cerave Sunscreen Bundle SPF 50 | Contains Mineral Sunscreen for Face SPF 50, 2.5 Ounce, and Mineral Body Sunscreen SPF 50, 5 Ounce 1 ea
# 107879                                                                                                                    CeraVe Hydrating Oil Cleanser 236ml
# 83064                                                       Cerave Moisturizing Cream With Pump For Normal To Dry Skin Value Pack of 2 x 19 Oz (Total 38 Oz)"
# 95664   C'est Moi Tinted Moisturizing Lotion SPF 30 | Gentle, Hydrating Formula Provides Broad Spectrum SPF Protection with Sheer, Buildable Coverage, Fra...
# 4509    C'est Moi Tinted Moisturizing Lotion SPF 30 | Gentle, Hydrating Formula Provides Broad Spectrum SPF Protection with Sheer, Buildable Coverage, Fra...
# 38057   C'est Moi Tinted Moisturizing Lotion SPF 30 | Gentle, Hydrating Formula Provides Broad Spectrum SPF Protection with Sheer, Buildable Coverage, Fra...
# 62664   C'est Moi Tinted Moisturizing Lotion SPF 30 | Gentle, Hydrating Formula Provides Broad Spectrum SPF Protection with Sheer, Buildable Coverage, Fra...
# 68802                                                       Clinique 'Moisture Surge' Tinted Moisturizer SPF 15 Provides a No-Makeup Look and Feel (Shade 02)
# 78162                  Murad Oil and Pore Control Mattifier Broad Spectrum SPF 45 | PA++++ | Travel Size - 0.8 Fl Oz - Moisturizer for Mattifying Facial Skin
#
#             store  final_score
# 10143      CeraVe    13.063652
# 31957      CeraVe    10.687904
# 107879     CeraVe     9.319592
# 83064     LUXSURE     8.185555
# 95664   C'est Moi     7.732594
# 4509    C'est Moi     7.629389
# 38057   C'est Moi     7.623445
# 62664   C'est Moi     7.560297
# 68802     unknown     5.124448
# 78162       Murad     4.921179
